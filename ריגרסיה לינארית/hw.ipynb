# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
data = {
    'Temperature': [14.2, 16.4, 11.9, 15.2, 18.5, 22.1, 19.4, 25.1, 23.4, 18.1, 22.6, 17.2],
    'Sales': [215, 325, 185, 332, 406, 522, 412, 614, 544, 421, 445, 408]
}

# %%
df = pd.DataFrame(data)
df.to_csv('ice_cream_data.csv', index=False)
print("קובץ ה-CSV נוצר בהצלחה!")
# Out:
# קובץ ה-CSV נוצר בהצלחה!

# %%
dataset = pd.read_csv('ice_cream_data.csv')
x = dataset[['Temperature']] 
y = dataset['Sales']

# %%
model=LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
b1 = model.coef_[0]
b0 = model.intercept_

# %%
print("-" * 30)
print(f"השיפוע (B1) הוא: {b1:.4f}")
print(f"נקודת החיתוך (B0) היא: {b0:.4f}")
print("-" * 30)
print(f"נוסחת הרגרסיה שלך היא: y = {b0:.2f} + {b1:.2f}x")
# Out:
# ------------------------------
# השיפוע (B1) הוא: 30.0879
# נקודת החיתוך (B0) היא: -159.4742
# ------------------------------
# נוסחת הרגרסיה שלך היא: y = -159.47 + 30.09x

# %%
print(model.score(X,y))
# Out:
# 0.9168189330919189

# %%
ty=model.predict([[-2]])
print(ty)
# Out:
# [-219.64987593]
# c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
yp=model.predict(X)

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y,yp))
# Out:
# 1211.3583679805115

# %%
import numpy as np

# נניח שאלו הנתונים שלך (y המקורי ו-y_pred מהמודל)
y_mean = np.mean(y)


# 1. SST - סך הכל השונות (המרחק מהממוצע)
sst = np.sum((y - y_mean)**2)

# 2. SSR - השונות שהסברנו (המרחק של החיזוי מהממוצע)
ssr = np.sum((yp - y_mean)**2)

# 3. SSE - השונות שלא הסברנו (המרחק מהחיזוי - הטעויות)
sse = np.sum((y - yp)**2)

print(f"SST: {sst:.2f}")
print(f"SSR: {ssr:.2f}")
print(f"SSE: {sse:.2f}")

# בדיקה: האם SSR + SSE קרוב ל-SST?
print(f"Check: {ssr + sse:.2f}")
# Out:
# SST: 174754.92
# SSR: 160218.62
# SSE: 14536.30
# Check: 174754.92

# %%
print(model.score(X,y))
# Out:
# 0.9168189330919189
